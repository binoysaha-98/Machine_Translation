# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My\ Drive/DL_assignments/A4/machine_translation/
 
import torch
import pickle
import numpy as np
from PIL import Image
from torchvision import transforms
import re
import torch.nn as nn
import torch.nn.functional as F
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/DL_assignments/A4/machine_translation/'
# /content/drive/.shortcut-targets-by-id/19L7QLz74qZ5PHcITBOkZ_LvBMdcyXM97/DL_assignments/A4/machine_translation

# %%
import string
f = open("train.en","r")
f = f.readlines()
english_sentences = []
for line in f:
  ws = np.array(re.split(" |\n",line)[:-1])
  table = str.maketrans('', '', string.punctuation)
  stripped = [w.translate(table) for w in ws]
  
  try:
      stripped.remove('')
  except ValueError:
      pass 
  english_sentences.append(stripped)
  # english_sentences.append(np.array(re.split(" |\n",line)[:-1]))
 
english_sentences = np.array(english_sentences)
 
f = open("train.ta","r")
f = f.readlines()
tamil_sentences = []
for line in f:
  ws = np.array(re.split(" |\n",line)[:-1])
  table = str.maketrans('', '', string.punctuation)
  stripped = [w.translate(table) for w in ws]
  
  try:
      stripped.remove('')
  except ValueError:
      pass 
  # tamil_sentences.append(np.array(re.split(" |\n",line)[:-1]))
  tamil_sentences.append(stripped)
 
tamil_sentences = np.array(tamil_sentences)
 
np.save("english_sentences_without_punctuation_train.npy",english_sentences)
np.save("tamil_sentences_without_punctuation_train.npy",tamil_sentences)

# %%
# Extracting unique words : vocabulary
english_sentences = np.load("english_sentences_without_punctuation_train.npy",allow_pickle=True)
tamil_sentences = np.load("tamil_sentences_without_punctuation_train.npy",allow_pickle=True)
english_sentences_dev = np.load("english_sentences_without_punctuation_dev.npy",allow_pickle=True)
tamil_sentences_dev = np.load("tamil_sentences_without_punctuation_dev.npy",allow_pickle=True)
def get_vocab(sentences):
  words = []
  for sentence in sentences:
    for word in sentence:
      words.append(word.lower())
  words.append("start_token")
  words.append("end_token")
  words = np.array(words).flatten()
  words = np.unique(words)
  return words
english_sentences = np.concatenate((english_sentences.reshape(1,-1),english_sentences_dev.reshape(1,-1)),axis=1).squeeze(0)
tamil_sentences = np.concatenate((tamil_sentences.reshape(1,-1),tamil_sentences_dev.reshape(1,-1)),axis=1).squeeze(0)

english_words = get_vocab(english_sentences)
tamil_words = get_vocab(tamil_sentences)


np.save("english_words_without_punctuation_dev.npy",english_words)
np.save("tamil_words_without_punctuation_dev.npy",tamil_words)
print(tamil_words)
print(tamil_words.shape)
print(english_words.shape)
# Out:
# ['' '00' '00மணிக்கு♪' ... '♪வேண்டும்குழந்தைசுற்றிகுழப்பம்' '♪ஷைன்பிரித்து'
#  '♪♪']
# (19338,)
# (10298,)

# %%
english_words = np.load("english_words.npy")
tamil_words = np.load("tamil_words.npy")

# %%
import string
tamil_words = tamil_words.tolist()
r = [i for i in string.punctuation]
for e in r:
  try:
    tamil_words.remove(e)
    print("d")
  except ValueError:
      pass 
print(len(tamil_words))

# %%
# Creating initial embeddings for all english words in the vocabulary 
 
input_file = open('../6B.300_embeddings.pkl', "rb")
glove = pickle.load(input_file)
idx_file = open('../6B.300_idx.pkl', "rb")
idx = pickle.load(idx_file)
target_vocab = np.load("english_words_without_punctuation_dev.npy")
matrix_len = target_vocab.shape[0]
weights_matrix = np.zeros((matrix_len + 2, 300))
words_found = 0
for i in range(matrix_len):
    print(i)
    try:
        weights_matrix[i] = glove[idx[target_vocab[i]]]
        words_found += 1
    except KeyError:
        weights_matrix[i] = np.random.normal(scale=0.6, size=(300, ))
weights_matrix[matrix_len] = np.random.normal(scale=0.6, size=(300, ))
weights_matrix[matrix_len+1] = np.random.normal(scale=0.6, size=(300, ))
np.save("initial_embeddings_without_punctuation_dev.npy",weights_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# 5383
# 5384
# 5385
# 5386
# 5387
# 5388
# 5389
# 5390
# 5391
# 5392
# 5393
# 5394
# 5395
# 5396
# 5397
# 5398
# 5399
# 5400
# 5401
# 5402
# 5403
# 5404
# 5405
# 5406
# 5407
# 5408
# 5409
# 5410
# 5411
# 5412
# 5413
# 5414
# 5415
# 5416
# 5417
# 5418
# 5419
# 5420
# 5421
# 5422
# 5423
# 5424
# 5425
# 5426
# 5427
# 5428
# 5429
# 5430
# 5431
# 5432
# 5433
# ...

# %%
#================================================================================================================================

# %%
# %cd drive/My\ Drive/DL_assignments/A4/machine_translation/
 
import torch
import pickle
import numpy as np
from PIL import Image
from torchvision import transforms
import re
import torch.nn as nn
import torch.nn.functional as F
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction
smoothie = SmoothingFunction().method1

np.random.seed(1)
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/DL_assignments/A4/machine_translation/'
# /content/drive/.shortcut-targets-by-id/19L7QLz74qZ5PHcITBOkZ_LvBMdcyXM97/DL_assignments/A4/machine_translation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Loading data
 
# english_words = np.load("english_words_without_punctuation_dev.npy",allow_pickle=True).tolist() # english vocabulary
# tamil_words = np.load("tamil_words_without_punctuation_dev.npy",allow_pickle= True).tolist() # tamil vocabulary
# initial_embeddings = np.load("initial_embeddings_without_punctuation_dev.npy",allow_pickle=True) # initial glove embeddings for english words 
# # english_sentences = np.load("english_sentences_shuffled_train.npy",allow_pickle=True) # English sentences
# # tamil_sentences = np.load("tamil_sentences_shuffled_train.npy",allow_pickle=True) # Tamil sentences
# english_sentences_dev = np.load("english_sentences_without_punctuation_test.npy",allow_pickle=True)
# tamil_sentences_dev = np.load("tamil_sentences_without_punctuation_test.npy",allow_pickle=True)

english_words = np.load("english_words_without_punctuation_dev.npy",allow_pickle=True).tolist() # english vocabulary
tamil_words = np.load("tamil_words_without_punctuation_dev.npy",allow_pickle= True).tolist() # tamil vocabulary
initial_embeddings = np.load("initial_embeddings_without_punctuation_dev_100.npy",allow_pickle=True) # initial glove embeddings for english words 
english_sentences_dev = np.load("english_sentences_without_punctuation_test.npy",allow_pickle=True) # English sentences
tamil_sentences_dev = np.load("tamil_sentences_without_punctuation_test.npy",allow_pickle=True) # Tamil sentences

# %%
english_sentences_dev = np.load("english_sentences_shuffled_dev.npy",allow_pickle=True)
tamil_sentences_dev = np.load("tamil_sentences_shuffled_dev.npy",allow_pickle=True)

# %%
english_sentences_dev = np.load("english_sentences_without_punctuation_dev.npy",allow_pickle=True)
tamil_sentences_dev = np.load("tamil_sentences_without_punctuation_dev.npy",allow_pickle=True)

# %%
print(len(tamil_words))
tamil_words_ = np.load("tamil_words_without.npy",allow_pickle=True).tolist()
print(len(set(tamil_words) - set(tamil_words_)))
# Out:
# 19338
# 588

# %%
# Do not execute

english_sentences = np.load("english_sentences_without_punctuation.npy",allow_pickle=True)
tamil_sentences = np.load("tamil_sentences_without_punctuation.npy",allow_pickle=True)
rng_state = np.random.get_state()
np.random.shuffle(english_sentences)
np.random.set_state(rng_state)
np.random.shuffle(tamil_sentences)
np.save("english_sentences_shuffled_train.npy",np.array(english_sentences[:25500]))
np.save("tamil_sentences_shuffled_train.npy",np.array(tamil_sentences[:25500]))
np.save("english_sentences_shuffled_dev.npy",np.array(english_sentences[25500:]))
np.save("tamil_sentences_shuffled_dev.npy",np.array(tamil_sentences[25500:]))

# %%
# RNN Encoder Decoder
 
class Network(nn.Module):
    def create_emb_layer(self,weights_matrix,flag):
        num_embeddings, embedding_dim = weights_matrix.size()
        if flag == True:
            emb_layer = nn.Embedding(num_embeddings, embedding_dim)
            emb_layer.load_state_dict({'weight': weights_matrix})
        else:
            emb_layer = nn.Embedding(len(tamil_words), embedding_dim)
        emb_layer.weight.requires_grad = True
        return emb_layer
        
    def __init__(self):
        super().__init__()
        
 
        self.hidden_size = 300
        self.emb_size = 100
        self.output_nodes = 300
        self.num_layers = 1
        self.en_embeddings = self.create_emb_layer(torch.from_numpy(initial_embeddings),True)
        self.ta_embeddings = self.create_emb_layer(torch.from_numpy(initial_embeddings),False)
        self.encoder_rnn = nn.LSTM(self.emb_size, self.hidden_size, self.num_layers, batch_first=True)
        
        self.decoder_rnn = nn.LSTM(self.emb_size, self.hidden_size, self.num_layers, batch_first=True)
 
        self.linear_layer = nn.Sequential(
            nn.Linear(self.hidden_size,self.output_nodes)
        )

        self.output_layer = nn.Sequential(
            nn.Linear(self.output_nodes,len(tamil_words))
        )
 
 
    def forward(self, x,y):
        '''
        x_out,y_out = self.encoder_rnn(torch.unsqueeze(self.en_embeddings(x),0))
        x_out,y_out = self.decoder_rnn(torch.unsqueeze(self.ta_embeddings(y),0),y_out)
        outs = self.linear_layer(x_out.squeeze(0))
        return self.output_layer(outs)
        '''
        out = []
        out_i = []
        first = True
        while True:
            if len(out) == 40:
              return out,out_i 
            if not first:  
                o = self.linear_layer(y_out)
                o = self.output_layer(o)
                o = torch.squeeze(o,0)
                v,i = torch.max(o,1)
                i = i.item()
                if i == len(tamil_words) - 1:
                    break
                elif i == len(tamil_words) - 2:
                    out.append("st")
                    out_i.append(-1)
                else:
                    out.append(tamil_words[i])
                    out_i.append(i)
            else:
                i = len(tamil_words) - 2
                first = False
                _,(y_out,s_out) = self.encoder_rnn(torch.unsqueeze(self.en_embeddings(x),0))
            
            if i != len(tamil_words) - 1:
                x_out,(y_out,s_out) = self.decoder_rnn(torch.unsqueeze(torch.unsqueeze(self.ta_embeddings(torch.tensor(i)),0),0),(y_out,s_out))
            else:
                break
        return out,out_i 
        #'''

# %%
print(len(tamil_words))
print(len(english_words))
# Out:
# 19338
# 10298

# %%
# Training 
 
#dev = torch.device("cpu")
 
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu" 
print("using {}".format(dev))
 
 
model = Network().to(dev)
criterion = nn.CrossEntropyLoss().to(dev)
# optimizer = torch.optim.Adam(params=model.parameters(),lr=0.0001,betas=(0.9,0.999))
optimizer = torch.optim.SGD(params=model.parameters(),lr=0.1)
train_from_saved_model = True
 
start_epoch = 20
num_epochs = 100

if train_from_saved_model:
    checkpoint = torch.load("model/model_epoch_25500_emb100_{}.pth".format(start_epoch))
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    #optimizer = torch.optim.Adam(params=model.parameters(),lr=0.1)
 
print(optimizer.param_groups[0]['lr'])
# optimizer.param_groups[0]['lr'] = 0.000001 
# print(optimizer.param_groups[0]['lr'])
 
optimizer = torch.optim.SGD(params=model.parameters(),lr=0.01)
# optimizer = torch.optim.SGD(params=model.parameters(),lr=0.0001)
# optimizer = torch.optim.Adam(params=model.parameters(),lr=0.0001,betas=(0.9,0.999))
 

for e in range(start_epoch + 1,start_epoch + num_epochs + 1):
    print(e)
    epoch_loss = 0
    optimizer.zero_grad()
    batch_size = 1
    d = 0
    for it in range(int(25500/batch_size)):
        loss = 0
        optimizer.zero_grad()
        # expected = english_sentences[it].tolist()
        expected = english_sentences[it]
        expected = [len(english_words) - 2] + [english_words.index(s.lower()) for s in expected]+ [len(english_words) - 1]
        expected_in = np.array(expected[:-1])
        # expected = tamil_sentences[it].tolist()
        expected = tamil_sentences[it]
        expected = [len(tamil_words) - 2] + [tamil_words.index(s.lower()) for s in expected]+ [len(tamil_words) - 1]
        expected_out = np.array(expected[1:])
        expected_in_ta  = np.array(expected[:-1])
        output = model(torch.from_numpy(expected_in).to(dev),torch.from_numpy(expected_in_ta).to(dev))        
        o = torch.squeeze(output,0)
        et = torch.from_numpy(expected_out).to(dev)
        if o.ndim == 1:
          o = o.unsqueeze(0)
        loss += criterion(o,et)
        epoch_loss += loss
        if d % 1000 == 0:
          print(d,epoch_loss/d)
        loss.backward()
        optimizer.step()
        d += 1
    print(epoch_loss/25500)
    print(e)
    if e % 5 == 0:
        torch.save({
                    'epoch': e,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': epoch_loss,
                    }, "model/model_epoch_25500_emb100_{}.pth".format(e))
        print("saved")
# Out:
# using cuda:0
# 0.1
# 21
# 0 tensor(inf, device='cuda:0', grad_fn=<DivBackward0>)
# 1000 tensor(1.4819, device='cuda:0', grad_fn=<DivBackward0>)
# 2000 tensor(1.4703, device='cuda:0', grad_fn=<DivBackward0>)
# 3000 tensor(1.4407, device='cuda:0', grad_fn=<DivBackward0>)
# 4000 tensor(1.4196, device='cuda:0', grad_fn=<DivBackward0>)
# 5000 tensor(1.3746, device='cuda:0', grad_fn=<DivBackward0>)
# 6000 tensor(1.3490, device='cuda:0', grad_fn=<DivBackward0>)
# 7000 tensor(1.3131, device='cuda:0', grad_fn=<DivBackward0>)
# 8000 tensor(1.2857, device='cuda:0', grad_fn=<DivBackward0>)
# 9000 tensor(1.2576, device='cuda:0', grad_fn=<DivBackward0>)
# 10000 tensor(1.2299, device='cuda:0', grad_fn=<DivBackward0>)
# 11000 tensor(1.2039, device='cuda:0', grad_fn=<DivBackward0>)
# 12000 tensor(1.1823, device='cuda:0', grad_fn=<DivBackward0>)
# 13000 tensor(1.1540, device='cuda:0', grad_fn=<DivBackward0>)
# 14000 tensor(1.1297, device='cuda:0', grad_fn=<DivBackward0>)
# ...

# %%
torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': epoch_loss,
            }, "model/model_epoch_final_131.pth")
print("saved")
# Out:
# saved

# %%
# Testing 
import matplotlib.pyplot as plt
dev = torch.device("cpu")

model = Network()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(),lr=0.1)

checkpoint = torch.load("model_epoch_25500_emb100_70.pth",map_location=torch.device('cpu'))
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
 
model.eval()
tot_score_1 = 0
tot_score_2 = 0
tot_score_3 = 0
tot_score_4 = 0
start = 0
end = 1000
refs = []
candidates = []
div1 = 0
div2 = 0
div3 = 0
div4 = 0
div = 0 
for d in range(start,end):
    print(d)
    
    expected = english_sentences_dev[d]

    e = [len(english_words) - 2]
    for s in expected:
      if s.lower() in english_words:
        e.append(english_words.index(s.lower()))
      else:
        e.append(len(english_words) - 2)
    e.append(len(english_words) - 1)
    expected_in = np.array(e[1:-1])
     
    # expected = [len(english_words) - 2] + [english_words.index(s.lower()) for s in expected]+ [len(english_words) - 1]
    # expected_in = np.array(expected[:-1])
    
    expected = tamil_sentences_dev[d]
    print(expected)
    # print(expected)
    # e = expected   
    # expected = [len(tamil_words) - 2] + [tamil_words.index(s.lower()) for s in expected]+ [len(tamil_words) - 1]
    # expected_out = np.array(expected[1:])
    # exp = expected_out[:-1]
    expected_out = np.array([0,0])
    output,out_i = model(torch.from_numpy(expected_in).to(dev),torch.from_numpy(expected_out).to(dev))        
    print(output)
    print()
    # input()
    # refs.append([exp])
    # candidates.append(out_i)
    
    # if len(out_i) >= 2:
    #   tot_score_1 += sentence_bleu([exp.tolist()], out_i,weights=(1, 0, 0, 0),smoothing_function=smoothie)
    #   tot_score_2 += sentence_bleu([exp.tolist()], out_i,weights=(0.5, 0.5, 0, 0),smoothing_function=smoothie)
    #   tot_score_3 += sentence_bleu([exp.tolist()], out_i,weights=(0.33, 0.33, 0.33, 0),smoothing_function=smoothie)
    #   tot_score_4 += sentence_bleu([exp.tolist()], out_i,weights=(0.25, 0.25, 0.25, 0.25),smoothing_function=smoothie)
    #   div += 1

    # if len(out_i) >= 4:
    #   tot_score_1 += bleu_score([output], [[e]],weights=(1, 0, 0, 0))
    #   div1 += 1
    # if len(out_i) >= 4:  
    #   tot_score_2 += bleu_score([output], [[e]],weights=(0.5, 0.5, 0, 0))
    #   div2 += 1
    # if len(out_i) >= 4:   
    #   tot_score_3 += bleu_score([output], [[e]],weights=(0.33, 0.33, 0.33, 0))
    #   div3 += 1
    # if len(out_i) >= 4:
    #   tot_score_4 += bleu_score([output], [[e]],weights=(0.25, 0.25, 0.25, 0.25))
    #   div4 += 1

    if len(out_i) >= 4:
        tot_score_1 += sentence_bleu([expected], output,weights=(1, 0, 0, 0),smoothing_function=smoothie)
        tot_score_2 += sentence_bleu([expected], output,weights=(0.5, 0.5, 0, 0),smoothing_function=smoothie)
        tot_score_3 += sentence_bleu([expected], output,weights=(0.33, 0.33, 0.33, 0),smoothing_function=smoothie)
        tot_score_4 += sentence_bleu([expected], output,weights=(0.25, 0.25, 0.25, 0.25),smoothing_function=smoothie)
        div += 1

    

print(div)
print(tot_score_1/div)
print(tot_score_2/div)
print(tot_score_3/div)
print(tot_score_4/div)
# tot_score_1 += corpus_bleu(refs, candidates,weights=(1, 0, 0, 0))
# tot_score_2 += corpus_bleu(refs, candidates,weights=(0.5, 0.5, 0, 0))
# tot_score_3 += corpus_bleu(refs, candidates,weights=(0.33, 0.33, 0.33, 0))
# tot_score_4 += corpus_bleu(refs, candidates,weights=(0.25, 0.25, 0.25, 0.25))
# print(np.unique(np.array(refs)))
# plt.hist(np.array(refs).flatten())
# plt.show()
# print(tot_score_1/div1)
# print(tot_score_2/div2)
# print(tot_score_3/div3)
# print(tot_score_4/div4)
# print(div1)
# print(div2)
# print(div3)
# print(div4)
print(div)
print(tot_score_1/div)
print(tot_score_2/div)
print(tot_score_3/div)
print(tot_score_4/div)
# Out:
# 0
# ['SIS', 'மூன்று', '36', 'வயது', 'நடுத்தர', 'ஊதியம்', 'கடந்த', 'மூன்று', 'ஆண்டுகளில்']
# ['மூன்று', 'நாட்கள்', 'கொடுங்கள்']
#
# 1
# ['நீங்கள்', 'தேர்வு', 'செய்ய', 'வேண்டும்', '']
# ['நீங்கள்', 'ஒரு', 'தேர்வு', 'செய்ய', 'வேண்டும்']
#
# 2
# ['பிட்ச்', 'நீங்கள்', 'நல்ல', 'உங்கள்', 'என்', 'என்', 'அலுவலக', 'outta']
# ['நீங்கள்', 'உங்கள்', 'கழுதை', 'அழைக்க', 'உங்கள்', 'கழுதை', 'கிடைக்கும்', 'வலது', 'அழைக்க', 'முடியாது']
#
# 3
# ['மற்றும்', 'உலக', 'எங்களை', 'பற்றி', 'மறக்க', 'முடியாது']
# ['மற்றும்', 'எங்களுக்கு', 'சுற்றி', 'கொல்ல', '', '', 'எங்களுக்கு', '']
#
# 4
# ['என்', 'செல்', 'போன்', 'எச்சரிக்கைகள்', 'மூலம்']
# ['என்', 'தொலைபேசி', 'ஒரு', 'தொலைபேசி', 'உள்ளன']
#
# 5
# ['இந்த', 'சாரணர்', 'கப்பல்', 'இருந்தது', 'வெற்றிடத்தை', 'செலுத்தப்படுகின்றன', 'ஆயிரக்கணக்கான', 'ஒன்றாகும்']
# ['இந்த', 'கப்பல்', 'இணைந்து', 'என்று', 'சுற்று', 'ஒரு', 'முக்கிய', 'துப்பாக்கி', 'சூட்டு']
#
# 6
# ['பெண்', 'பாடல்உள்ளதுஒரு', 'இருண்ட', 'மற்றும்', 'ஒரு', 'நான்', 'வாழ்க்கை', 'பதற்றமான', 'பக்க']
# ...

# %%
Some Good results:

GT:    ['இது', 'ரொம்ப', 'காலமாக', 'நான்', 'நினைத்தேன்', 'நீண்ட', 'காலமாக', 'இது', 'பற்றி', 'நான்', 'நிச்சயமாக', 'இல்லை']
Pred:  ['இது', 'ரொம்ப', 'காலமாக', 'நான்', 'நினைத்தேன்', 'நீண்ட', 'காலமாக', 'இது', 'பற்றி', 'நான்', 'நிச்சயமாக', 'இல்லை']

GT:    ['நான்', 'அனைத்து', 'மீண்டும்', 'வெள்ளம்', 'வந்து', 'உங்கள்', 'கழுத்து', 'வகை', 'உணவு', 'மீன்', 'கணம்']
Pred:  ['நான்', 'அனைத்து', 'மீண்டும்', 'வெள்ளம்', 'வந்து', 'உங்கள்', 'கழுத்து', 'வகை', 'உணவு', 'மீன்', 'கணம்']

Some Bad results:

GT:    ['ஸ்மைலி', 'எப்போதும்', 'பற்றி', 'உள்ள', 'ஒரு', 'ரோல்', 'போகிறேன்', 'இருந்த', 'ஒரு', 'பையன்', 'மீது', 'yabbering']
Pred:  ['ஸ்மைலி', 'எப்போதும்', 'பற்றி', 'எப்போதும்', 'உள்ள', 'ஒரு', 'ரோல்', 'போகிறேன்', 'என்று', 'ஒரு', 'டாகிங்', 'தூக்கம்']

GT:    ['நாம்', 'மட்டும்', '100', 'டைனமைட்', 'என்ற', 'குச்சிகள்', 'மற்றும்', 'ஒரு', 'சில', 'ஆயுதங்கள்', 'கிடைத்தது']
Pred:  ['நாம்', 'மட்டும்', '100', 'டைனமைட்', 'நான்', 'ஒரு', 'இருந்தது', 'மற்றும்', 'மேலும்', 'இரத்த', 'என்றார்']

# %%
Some Good results:

GT:               ['நான்', 'அனைத்து', 'மீண்டும்', 'வெள்ளம்', 'வந்து', 'உங்கள்', 'கழுத்து', 'வகை', 'உணவு', 'மீன்', 'கணம்']
LSTM:             ['நான்', 'அனைத்து', 'மீண்டும்', 'வெள்ளம்', 'வந்து', 'உங்கள்', 'கழுத்து', 'வகை', 'உணவு', 'மீன்', 'கணம்']
LSTM [attention]: ['நான்', 'அனைத்து', 'மீண்டும்', 'வெள்ளம்', 'வந்து', 'உங்கள்', 'கழுத்து', 'வகை', 'உணவு', 'மீன்', 'கணம்']

GT:               ['இது', 'ஆபத்தானது', 'ஆனால்', 'ஒரு', 'தொடர்பில்லாத', 'கொடை', 'HLB', 'அடிப்படையில்', 'காணலாம்', 'மற்றும்',
                   'DR', 'ஹிஸ்டோகம்பார்டிபிளிட்டி']
LSTM:             ['இது', 'ஆபத்தானது', 'ஆனால்', 'ஒரு', 'தொடர்பில்லாத', 'கொடை', 'hlb', 'அடிப்படையில்', 'காணலாம்', 'மற்றும்',
                   'dr', 'ஹிஸ்டோகம்பார்டிபிளிட்டி']
LSTM [attention]: ['இது', 'ஆபத்தானது', 'ஆனால்', 'ஒரு', 'தொடர்பில்லாத', 'கொடை', 'hlb', 'அடிப்படையில்', 'காணலாம்', 'மற்றும்',
                   'dr', 'ஹிஸ்டோகம்பார்டிபிளிட்டி']

Some Bad results:

GT:               ['ஸ்மைலி', 'எப்போதும்', 'பற்றி', 'உள்ள', 'ஒரு', 'ரோல்', 'போகிறேன்', 'இருந்த', 'ஒரு', 'பையன்', 'மீது',
                   'yabbering']
LSTM:             ['ஸ்மைலி', 'எப்போதும்', 'பற்றி', 'எப்போதும்', 'உள்ள', 'ஒரு', 'ரோல்', 'போகிறேன்', 'என்று', 'ஒரு', 'டாகிங்', 
                   'தூக்கம்']
LSTM [attention]: ['ஸ்மைலி', 'எப்போதும்', 'மட்டும்', 'உள்ள', 'ஒரு', 'ரோல்', 'போகிறேன்', 'இருந்த', 'ஒரு', 'பையன்', 'மீது',
                   'yabbering', 'இருந்தது']

GT:               ['அவர்', 'என்னை', 'அங்கு', 'ஒரு', 'புத்தகம்', 'பெற', 'ஒரு', 'சில', 'உதவிகள்', 'பணம்', 'இருந்தது']
LSTM:             ['எனக்கு', 'ஒரு', 'வித்தியாசமும்', 'பெற', 'நான்', 'ஜூலியா', 'எந்த', 'நேரடி', 'கிடைச்சுது']
LSTM [attention]: ['அவர்', 'என்னை', 'அங்கு', 'ஒரு', 'புத்தகம்', 'இருந்தது', 'அங்கு', 'கிடைக்கும்', 'மற்றும்', 'ஒரு', 'புத்தகம்', 
                   'இருந்தது']

# %%
Some Good results:

GT:               ['நீயும்', 'நானும்']
LSTM:             ['நீயும்', 'நானும்']
LSTM [attention]: ['நீயும்', 'நானும்']

GT:               ['என்றால்', 'அது', 'ஒரு', 'தனி', 'விமானம்', 'கண்டுபிடி']
LSTM:             ['என்றால்', 'அது', 'ஒரு', 'தனி', 'விமானம்', 'கண்டுபிடி']
LSTM [attention]: ['என்றால்', 'அது', 'ஒரு', 'தனி', 'விமானம்', 'கண்டுபிடி']

GT:               ['நான்', 'பற்றி', 'பேசுகிறேன்', 'என்ன', 'தெரியும்']
LSTM:             ['நான்', 'பற்றி', 'பேசுகிறேன்', 'என்ன', 'தெரியுமா']
LSTM [attention]: ['நான்', 'பற்றி', 'பேசுகிறேன்', 'என்ன', 'தெரியுமா']

Some Bad results:

GT:               ['என்', 'தந்தை', 'துறையில்', 'வேலை']
LSTM:             ['என்', 'தந்தை', 'மீது', 'துறையில்', 'வேலை']
LSTM [attention]: ['என்', 'தந்தை', 'துறையில்', 'வேலை']

GT:               ['ஆமாம்', 'நீங்கள்', 'ஒரு', 'நிமிடம்', 'எனக்கு', 'மறைக்க', 'முடியும்']
LSTM:             ['ஆமாம்', 'நீங்கள்', 'ஒரு', 'நிமிடம்', 'என்னை', 'அழைத்து', 'தடுக்க', 'விடு']
LSTM [attention]: ['ஆமாம்', 'நான்', 'ஒரு', 'நிமிடம்', 'பிறகு', 'என்னை', 'முடியும்']

# %%
# Final - training - 350 - model_25500
0.7823005315016393
0.7749563310209725
0.6920908573567588
0.5978684383317148

# valid
0.1533279066513026
0.1038122698462236
0.07913700192080035
0.06458734552349828

# testing
0.06359491017994262
0.018038032070748836
0.012343133754584035
0.010023340805385165

# Final - training - 100 - model_25500
0.5535165194843175
0.5384041530381635
0.4592242418147869
0.37952939450929246

# validation
0.17510453250418465
0.1112468993733707
0.08273902906300264
0.06633668972003182

# testing 
0.07120803867755361
0.022354654834615455
0.015107626073711189
0.012423691501014737

# training - 70 - model_25500_emb100
0.9725607515482689
0.9676863318520866
0.880152332394848
0.7610134860868712

# validation 
0.29622102104968634
0.19358283534299364
0.1431996235866549
0.11742090332411388

# testing 
0.1405632907009881
0.05025373846226176
0.0313545273435601
0.024585420135737286
